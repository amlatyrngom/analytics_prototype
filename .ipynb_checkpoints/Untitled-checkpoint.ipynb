# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import altair as alt
from altair import datum, expr
import math
alt.renderers.enable('mimetype')
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
all_budgets = set()
results_folder = "results32"

def compute_speedup(df, default, prev_df = None):
    df = df.copy()
    df["query_num"] = [int(df.query_name[i][len("query"):]) for i in range(len(df))]
    default = default[default.query_name != "query60"].reset_index()
    df = df[df.query_num != 60].reset_index()
    if prev_df is not None:
        new_rts = np.minimum(df.running_time, prev_df.running_time)
        # print(f"Diff count {(new_rts != df.running_time).sum()}")
        df.running_time = new_rts
    else:
        if df.expt_name[0] != "smartid":
            new_rts = np.minimum(df.running_time, default.running_time)
            # print(f"Diff count {(new_rts != df.running_time).sum()}")
            df.running_time = new_rts
    df["speedup"] = default.running_time / df.running_time
    df["log_speedup"] = np.log(df.speedup)
    df["color"] = df.log_speedup.map(lambda x: "Speedup" if x >= 0 else "Slowdown")
    global all_budgets
    all_budgets = all_budgets.union(set(df.budget))
    return df

def complete_budgets(df, default):
    min_budget = np.min(df.budget)
    max_budget = np.max(df.budget)
    dfs = [df]
    for budget in all_budgets:
        if budget < min_budget:
            to_prepend = default[default.budget == 0].copy()
            to_prepend.expt_name = [df.expt_name[0] for i in range(len(to_prepend))]
            to_prepend.budget = [budget for i in range(len(to_prepend))]
            dfs = [to_prepend] + dfs
        if budget > max_budget:
            to_append = df[df.budget == max_budget].copy()
            to_append.budget = [budget for i in range(len(to_append))]
            dfs = dfs + [to_append]
    
    df = pd.concat(dfs).reset_index(drop=True)
    df["nice_budget"] = df.budget*64
    return df
    

def read_default():
    filename = f"{results_folder}/default_results.csv"
    df = pd.read_csv(filename, names=["expt_name", "query_name", "running_time"], index_col=False)
    df["budget"] = [0 for i in range(len(df))]
    df = compute_speedup(df, df)
    return df

def read_sip(default):
    filename = f"{results_folder}/default_results_with_sip.csv"
    df = pd.read_csv(filename, names=["expt_name", "query_name", "running_time"], index_col=False)
    df["budget"] = [0 for i in range(len(df))]
    df["expt_name"] = ["sip" for i in range(len(df))]
    df = compute_speedup(df, default)
    return df

def read_simple_smartids(default):
    filename = f"{results_folder}/simple_smartids_results.csv"
    df = pd.read_csv(filename, names=["expt_name", "query_name", "running_time"], index_col=False)
    df["budget"] = [0 for i in range(len(df))]
    df = compute_speedup(df, default)
    return df

def read_index(default):
    all_dfs = []
    prev_df = None
    for budget in [2, 4, 6, 8, 10]:
        filename = f"{results_folder}/index_results_{budget}.csv"
        df = pd.read_csv(filename, names=["expt_name", "query_name", "budget", "running_time"], index_col=False)
        df = compute_speedup(df, default, prev_df)
        all_dfs.append(df)
        prev_df = df
    return pd.concat(all_dfs).reset_index(drop=True)
    
    
def read_mat_view(default):
    all_dfs = []
    prev_df = None
    for budget in [2, 4, 6, 8, 10, 16, 32, 48, 64, 80, 96, 112, 128]:
        reset48 = False
        if budget == 48 and results_folder == "results32":
            reset48 = True
            budget = 32 # TODO: Add 48 expt.
        filename = f"{results_folder}/mat_view_results_{budget}.csv"
        df = pd.read_csv(filename, names=["expt_name", "query_name", "budget", "running_time"], index_col=False)
        if reset48:
            df.budget = [48 for i in range(len(df))]
        df = compute_speedup(df, default, prev_df)
            
        all_dfs.append(df)
        prev_df = df
    return pd.concat(all_dfs).reset_index(drop=True)

# %%
default = read_default()
# print(default.head())

smartids = read_simple_smartids(default)
print(smartids.head())


sip = read_sip(default)
sip_v_smartids = read_sip(smartids)
smartids_v_sip = read_simple_smartids(sip)
# print(sip.head())


index = read_index(default)
index_v_smartids = read_index(smartids)
# print(index.head())

mat_view = read_mat_view(default)
mat_view_v_smartids = read_mat_view(smartids)
# print(mat_view.tail())

print(all_budgets)
index
# Out:
#    index expt_name query_name  running_time  budget  query_num   speedup  \
# 0      0   smartid     query1      0.017521       0          1  2.649056
# 1      1   smartid     query2      0.011616       0          2  1.777845
# 2      2   smartid     query3      0.011254       0          3  2.020345
# 3      3   smartid     query4      0.011752       0          4  2.403157
# 4      4   smartid     query5      0.053464       0          5  1.524929
#
#    log_speedup    color
# 0     0.974203  Speedup
# 1     0.575402  Speedup
# 2     0.703268  Speedup
# 3     0.876783  Speedup
# 4     0.421948  Speedup
# {0, 32, 2, 64, 4, 96, 6, 128, 8, 10, 16, 48, 80, 112}
#      index expt_name query_name  budget  running_time  query_num   speedup  \
# 0        0     index     query1       2      0.032228          1  1.440211
# 1        1     index     query2       2      0.008584          2  2.405840
# 2        2     index     query3       2      0.007866          3  2.890375
# 3        3     index     query4       2      0.015697          4  1.799118
# 4        4     index     query5       2      0.057946          5  1.406964
# ..     ...       ...        ...     ...           ...        ...       ...
# 340     65     index    query66      10      0.916879         66  1.018791
# 341     66     index    query67      10      0.777960         67  1.007887
# 342     67     index    query68      10      0.267766         68  1.000000
# 343     68     index    query69      10      0.168755         69  1.062907
# 344     69     index    query70      10      4.833318         70  1.000000
#
#      log_speedup    color
# 0       0.364790  Speedup
# 1       0.877899  Speedup
# 2       1.061386  Speedup
# 3       0.587296  Speedup
# 4       0.341434  Speedup
# ..           ...      ...
# 340     0.018617  Speedup
# 341     0.007856  Speedup
# 342     0.000000  Speedup
# 343     0.061008  Speedup
# 344     0.000000  Speedup
#
# [345 rows x 9 columns]

# %%
def plot_speedup(name, df, budget):
    df = df[df.budget==budget]
    print(df.head())
    return alt.Chart(df).mark_bar().encode(
        x=alt.X("query_num:O", axis=alt.Axis(title="Query Number")),
        y=alt.Y("log_speedup:Q", axis=alt.Axis(labelExpr=expr.format(expr.exp(datum.value), ',.1f'), format=",.0f", title="speedup")),
        color=alt.Color('color:N', scale=alt.Scale(domain=["Speedup", "Slowdown"], range=["green", "red"]))
    ).properties(
        title={
            "text": f"{name} with {budget*64}MB additional space"
        }
    )

# %%
chart = plot_speedup("SmartIDs vs Default", smartids, 0)
chart
# Out:
#   expt_name query_name  running_time  budget  query_num   speedup  \
# 0   smartid     query1      0.018408       0          1  2.604593
# 1   smartid     query2      0.010142       0          2  2.206612
# 2   smartid     query3      0.011175       0          3  2.180454
# 3   smartid     query4      0.012839       0          4  2.332422
# 4   smartid     query5      0.049910       0          5  1.926431
#
#    log_speedup    color
# 0     0.957277  Speedup
# 1     0.791458  Speedup
# 2     0.779533  Speedup
# 3     0.846907  Speedup
# 4     0.655669  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("SIP vs Default", sip, 0)
chart
# Out:
#   expt_name query_name  running_time  budget  query_num   speedup  \
# 0       sip     query1      0.038903       0          1  1.232423
# 1       sip     query2      0.016163       0          2  1.384653
# 2       sip     query3      0.015786       0          3  1.543518
# 3       sip     query4      0.022899       0          4  1.307706
# 4       sip     query5      0.070004       0          5  1.373466
#
#    log_speedup    color
# 0     0.208982  Speedup
# 1     0.325450  Speedup
# 2     0.434065  Speedup
# 3     0.268274  Speedup
# 4     0.317338  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Index vs Default", index, 4)
chart
# Out:
#    expt_name query_name  budget  running_time  query_num   speedup  \
# 70     index     query1       4      0.033028          1  1.451645
# 71     index     query2       4      0.009490          2  2.358207
# 72     index     query3       4      0.008739          3  2.788226
# 73     index     query4       4      0.016391          4  1.826860
# 74     index     query5       4      0.059730          5  1.609716
#
#     log_speedup    color
# 70     0.372697  Speedup
# 71     0.857902  Speedup
# 72     1.025406  Speedup
# 73     0.602599  Speedup
# 74     0.476058  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Index vs Default", index, 8)
chart
# Out:
#     expt_name query_name  budget  running_time  query_num   speedup  \
# 210     index     query1       8      0.033053          1  1.450557
# 211     index     query2       8      0.009514          2  2.352339
# 212     index     query3       8      0.009024          3  2.699984
# 213     index     query4       8      0.016547          4  1.809663
# 214     index     query5       8      0.059652          5  1.611819
#
#      log_speedup    color
# 210     0.371948  Speedup
# 211     0.855410  Speedup
# 212     0.993246  Speedup
# 213     0.593140  Speedup
# 214     0.477363  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Mat View vs Default", mat_view, 32)
chart
# Out:
#      index expt_name query_name  budget  running_time  query_num   speedup  \
# 414      0  mat_view     query1      32      0.016718          1  2.867950
# 415      1  mat_view     query2      32      0.012964          2  1.726293
# 416      2  mat_view     query3      32      0.015480          3  1.574022
# 417      3  mat_view     query4      32      0.013763          4  2.175742
# 418      4  mat_view     query5      32      0.043158          5  2.227803
#
#      log_speedup    color
# 414     1.053598  Speedup
# 415     0.545976  Speedup
# 416     0.453634  Speedup
# 417     0.777370  Speedup
# 418     0.801016  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Mat View vs Default", mat_view, 64)
chart
# Out:
#      index expt_name query_name  budget  running_time  query_num   speedup  \
# 552      0  mat_view     query1      64      0.016388          1  2.925708
# 553      1  mat_view     query2      64      0.012797          2  1.748801
# 554      2  mat_view     query3      64      0.015261          3  1.596639
# 555      3  mat_view     query4      64      0.013586          4  2.204122
# 556      4  mat_view     query5      64      0.043580          5  2.206215
#
#      log_speedup    color
# 552     1.073537  Speedup
# 553     0.558930  Speedup
# 554     0.467901  Speedup
# 555     0.790329  Speedup
# 556     0.791278  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Mat View vs Default", mat_view, 128)
chart
# Out:
#     expt_name query_name  budget  running_time  query_num   speedup  \
# 840  mat_view     query1     128      0.017243          1  2.780614
# 841  mat_view     query2     128      0.013434          2  1.665879
# 842  mat_view     query3     128      0.016083          3  1.515046
# 843  mat_view     query4     128      0.014156          4  2.115388
# 844  mat_view     query5     128      0.049886          5  1.927363
#
#      log_speedup    color
# 840     1.022672  Speedup
# 841     0.510353  Speedup
# 842     0.415446  Speedup
# 843     0.749238  Speedup
# 844     0.656153  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Index vs SmartIDs", index_v_smartids, 8)
chart
# Out:
#     expt_name query_name  budget  running_time  query_num   speedup  \
# 210     index     query1       8      0.033053          1  0.556923
# 211     index     query2       8      0.009514          2  1.066041
# 212     index     query3       8      0.009024          3  1.238267
# 213     index     query4       8      0.016547          4  0.775873
# 214     index     query5       8      0.059652          5  0.836686
#
#      log_speedup     color
# 210    -0.585329  Slowdown
# 211     0.063952   Speedup
# 212     0.213713   Speedup
# 213    -0.253767  Slowdown
# 214    -0.178306  Slowdown
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("Mat View vs SmartIDs", mat_view_v_smartids, 128)
chart
# Out:
#     expt_name query_name  budget  running_time  query_num   speedup  \
# 840  mat_view     query1     128      0.017243          1  1.067581
# 841  mat_view     query2     128      0.013434          2  0.754949
# 842  mat_view     query3     128      0.016083          3  0.694831
# 843  mat_view     query4     128      0.014156          4  0.906949
# 844  mat_view     query5     128      0.049886          5  1.000484
#
#      log_speedup     color
# 840     0.065395   Speedup
# 841    -0.281105  Slowdown
# 842    -0.364087  Slowdown
# 843    -0.097669  Slowdown
# 844     0.000483   Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart = plot_speedup("SmartIDs vs SIP", smartids_v_sip, 0)
chart
# Out:
#   expt_name query_name  running_time  budget  query_num   speedup  \
# 0   smartid     query1      0.018408       0          1  2.113392
# 1   smartid     query2      0.010142       0          2  1.593620
# 2   smartid     query3      0.011175       0          3  1.412651
# 3   smartid     query4      0.012839       0          4  1.783598
# 4   smartid     query5      0.049910       0          5  1.402605
#
#    log_speedup    color
# 0     0.748294  Speedup
# 1     0.466008  Speedup
# 2     0.345468  Speedup
# 3     0.578633  Speedup
# 4     0.338332  Speedup
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
# 50th Percentile
def q25(x):
    return x.quantile(0.25)

# 75th Percentile
def q75(x):
    return x.quantile(0.75)

# 90th Percentile
def q90(x):
    return x.quantile(0.90)


def compute_stats(df):
    res = df.groupby(by=['expt_name', 'budget']).agg({'log_speedup': ['min', 'max', 'median', q25, q75, q90], 'running_time': 'sum'})
    res.columns = ["min_speedup", "max_speedup", "median_speedup", "q25_speedup", "q75_speedup", "q90_speedup", "total_running_time"]
    res = res.reset_index()
    return res

# %%
sip_complete = complete_budgets(sip, default)
smartids_complete = complete_budgets(smartids, default)
index_complete = complete_budgets(index, default)
mat_view_complete = complete_budgets(mat_view, default)
complete_df = pd.concat([sip_complete, smartids_complete, index_complete, mat_view_complete]).reset_index()
complete_df_stats = compute_stats(complete_df)

alt.Chart(complete_df[complete_df.budget <= 128]).mark_boxplot(extent='min-max').encode(
    x=alt.X('expt_name:N', axis=None),
    y=alt.Y("log_speedup:Q", axis=alt.Axis(labelExpr=expr.format(expr.exp(datum.value), ',.1f'), format=",.0f", title="speedup")),
    column=alt.Column("nice_budget:O", title="Budget in MB"),
    color=alt.Color("expt_name:N", title="Optimization"),
)
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
def make_stats_plot(to_plot):
    names = {
        "max_speedup": "Maximum Speedup",
        "q90_speedup": "90th Percentile Speedup",
        "q75_speedup": "Q3 Speedup",
        "median_speedup": "Median Speedup",
        "q25_speedup": "Q1 Speedup",
        "min_speedup": "Min Speedup"
    }
    return alt.Chart(complete_df_stats).mark_line().encode(
        x=alt.X('budget:O'),
        y=alt.Y(f"{to_plot}:Q", axis=alt.Axis(labelExpr=expr.format(expr.exp(datum.value), ',.2f'), format=",.0f", title="speedup"),
                scale=alt.Scale(domain=(float(complete_df_stats[to_plot].min() - 0.05), float(complete_df_stats[to_plot].max() + 0.1)))),
        # column=alt.Column("nice_budget:O", title="Budget in MB"),
        color=alt.Color("expt_name:N", title="Optimization"),
    ).properties(
        title={
            'text': f"{names[to_plot]} per Budget"
        }
    )

(make_stats_plot("max_speedup") | make_stats_plot("q90_speedup") | make_stats_plot("q75_speedup"))
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
(make_stats_plot("median_speedup") | make_stats_plot("q25_speedup") | make_stats_plot("min_speedup"))
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
